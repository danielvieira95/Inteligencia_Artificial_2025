# %%
# importando as bibliotecas
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Realizar a leitura do meu arquivo csv
df = pd.read_csv('basededados/monitoramento_tempo.csv',sep=',')

# %%
# exibindo as primeiras linhas do dataframe
df.head() # exibe as 4 primeiras linhas do dataframe
# Out:
#    temperatura  pressão  humidade  direção do vento  velocidade do vento  \
# 0   282.080000   1024.0      81.0               0.0                  0.0
# 1   282.080000   1024.0      81.0               0.0                  0.0
# 2   282.083252   1024.0      80.0               4.0                  0.0
# 3   282.091866   1024.0      80.0              18.0                  0.0
# 4   282.100481   1024.0      80.0              31.0                  0.0
#
#   dia_da_semana                 data
# 0       Domingo  2012-10-01 12:00:00
# 1       Domingo  2012-10-01 13:00:00
# 2       Domingo  2012-10-01 14:00:00
# 3       Domingo  2012-10-01 15:00:00
# 4       Domingo  2012-10-01 16:00:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45253 entries, 0 to 45252
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   temperatura          45253 non-null  float64
#  1   pressão              45253 non-null  float64
#  2   humidade             45253 non-null  float64
#  3   direção do vento     45253 non-null  float64
#  4   velocidade do vento  45253 non-null  float64
#  5   dia_da_semana        45253 non-null  object
#  6   data                 45253 non-null  object
# dtypes: float64(5), object(2)
# memory usage: 2.4+ MB

# %%
# importa a biblioteca datetime 
import datetime # Biblioteca que permite a transformaçao da data que era um object
# em datetime
df['data'] = pd.to_datetime(df['data']) # converti a data de object para datetime
plt.figure(figsize=(15,8))
plt.plot(df['data'],df['temperatura'])
plt.xlabel('Data e hora')
plt.ylabel('Temperatura')
# Out:
# Text(0, 0.5, 'Temperatura')

# %%
fig = plt.figure(figsize=(10,8)) # crio uma variavel fig para armazenar o tamanho da figura
eixo = fig.add_axes([0,0,1,1]) # define o tamanho dos eixos do grafico
eixo.plot(df['data'],df['temperatura']/10,color='red',lw=0.2,linestyle='--')
eixo.set_title('Temperatura no momento',fontsize=25) # titulo do grafico
eixo.legend(['temperatura'],loc='lower right', fontsize =15) # loc - localizaçao da legenda
eixo.set_xlabel('Ano',fontsize=20)
eixo.set_ylabel('Temperatura',fontsize=20)
# Out:
# Text(0, 0.5, 'Temperatura')

# %%
# Selecionando o periodo da base de dados

fig = plt.figure(figsize=(15,8))
plt.rcParams['font.size']='20'
eixo= fig.add_axes([0,0,1,1])
eixo.plot(df['data'],df['temperatura'],color='b',lw=0.5,linestyle='--')
eixo.set_xlim(datetime.datetime(2015,1,1),datetime.datetime(2015,12,31)) # 
# xlim define o valor inicial e o valor final
eixo.set_title('Temperatura - Ano 2015',fontsize=25)
eixo.legend(['temperatura'],fontsize=20)
eixo.set_xlabel('Ano',fontsize=20)
# Out:
# Text(0.5, 0, 'Ano')
